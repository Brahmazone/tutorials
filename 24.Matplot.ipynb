# %%
import matplotlib.pyplot as mp
import numpy as np

# %%
rand_number = np.random.random(10)

# %%
rand_number
# Out:
# array([0.48281384, 0.93488715, 0.12112822, 0.76121183, 0.84177894,
#        0.04726705, 0.4893955 , 0.49592455, 0.317264  , 0.9784596 ])

# %%
x_axis = rand_number

# %%
y_axis = [0.5,1,2,3,4,0.5,1,2,3,4]
z_axis = [2,1,2,4,4,67,1,2,3,4]

# %%
matplotlib.pyplot.plot(x_axis,y_axis)

# %%
matplotlib.pyplot.plot(x_axis,y_axis, "*")
matplotlib.pyplot.show()
matplotlib.pyplot.plot(x_axis,(z_axis), "--")

# %%
fig = mp.figure()
matplotlib.pyplot.plot(x_axis,y_axis, "*")
matplotlib.pyplot.plot(x_axis,(z_axis), "--")
fig.savefig('matplotimg.png')

# %%
mp.style.use("seaborn-whitegrid")

# %%
mp.style.use("seaborn-whitegrid")
graph = mp.figure()
ax = mp.axes()

# %%
x_axis
import numpy as np

# %%
mp.plot(x_axis, np.sin(x_axis))

# %%
x = np.linspace(0,10,1000)

# %%
x
# Out:
# array([ 0.        ,  0.01001001,  0.02002002,  0.03003003,  0.04004004,
#         0.05005005,  0.06006006,  0.07007007,  0.08008008,  0.09009009,
#         0.1001001 ,  0.11011011,  0.12012012,  0.13013013,  0.14014014,
#         0.15015015,  0.16016016,  0.17017017,  0.18018018,  0.19019019,
#         0.2002002 ,  0.21021021,  0.22022022,  0.23023023,  0.24024024,
#         0.25025025,  0.26026026,  0.27027027,  0.28028028,  0.29029029,
#         0.3003003 ,  0.31031031,  0.32032032,  0.33033033,  0.34034034,
#         0.35035035,  0.36036036,  0.37037037,  0.38038038,  0.39039039,
#         0.4004004 ,  0.41041041,  0.42042042,  0.43043043,  0.44044044,
#         0.45045045,  0.46046046,  0.47047047,  0.48048048,  0.49049049,
#         0.5005005 ,  0.51051051,  0.52052052,  0.53053053,  0.54054054,
#         0.55055055,  0.56056056,  0.57057057,  0.58058058,  0.59059059,
#         0.6006006 ,  0.61061061,  0.62062062,  0.63063063,  0.64064064,
# ...

# %%
mp.plot(x, np.sin(x))

# %%
mp.plot(x, np.sin(x))
mp.plot(x, np.cos(x))

# %%
mp.plot(x, np.sin(x-0), color = 'red')
mp.plot(x, np.cos(x -1), color = 'g')
mp.plot(x, np.cos(x -2), color = 'blue')
mp.plot(x, np.cos(x -3), color = 'orange')
mp.plot(x, np.cos(x -4), color = '#FED994')

# %%
mp.plot(x, np.sin(x-0), color = 'red', linestyle="solid")
mp.plot(x, np.cos(x -1), color = 'g',linestyle="dashed")
mp.plot(x, np.cos(x -2), color = 'blue',linestyle="dotted")

# %%
principle = [100,200, 300,400,500,600]
profit = [10,0,44,78,0,0]
loss=[0,-30,0,0,-23,-33]

# %%
mp.plot(principle, profit, color = 'red', linestyle="solid")
mp.plot(principle, loss, color = 'g',linestyle="dashed")

# %%
mp.plot(principle, profit, color = 'red', linestyle="--")
mp.plot(principle, loss, color = 'g',linestyle=":")

# %%
mp.plot(principle, profit, "-b")

# %%
mp.plot(x, np.sin(x-0), color = 'red', linestyle="solid")

# %%
mp.plot(x, np.sin(x-0), color = 'red', linestyle="solid")
mp.xlim(-1,20)
mp.ylim(-2,3)
# Out:
# (-2, 3)

# %%
mp.plot(x, np.sin(x-0), color = 'red', linestyle="solid")
mp.axis([-1,20, -2,3])
# Out:
# [-1, 20, -2, 3]

# %%
mp.plot(x, np.sin(x-0), color = 'red', linestyle="solid", label = "sin(x)")
mp.plot(x, np.cos(x -1), color = 'g',linestyle="dashed", label = "cos(x)")
mp.axis([-1,20, -2,3])
mp.title("Sign wave on random numbers in numpy")
mp.xlabel("sign wave values")
mp.ylabel("random values from numpy")
mp.legend()

# %%
mp.scatter(x_axis, y_axis,marker = "o")

mp.title("Sign wave on random numbers in numpy")
mp.xlabel("sign wave values")
mp.ylabel("random values from numpy")
# Out:
# Text(0, 0.5, 'random values from numpy')

# %%
x = np.random.random(100)

# %%
y = np.random.random(100)

# %%
color = np.random.random(100)

# %%
mp.scatter(x, y, c = color, s =1000, alpha=0.2)
mp.colorbar()

# %%
data = np.random.randn(1000)

# %%
dat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-7ad2c836519b> in <module>
# ----> 1 dat
#
# NameError: name 'dat' is not defined

# %%
data
# Out:
# array([-8.42842120e-01, -1.98724692e+00, -5.67194246e-01, -4.15460166e-01,
#         7.71239786e-01,  5.77110916e-01,  6.34024279e-01, -7.93230169e-01,
#        -9.11192518e-01, -9.07400212e-01, -1.37449533e+00,  2.80517784e-01,
#        -9.17323556e-01,  2.85494339e+00,  5.74681098e-01, -1.26883435e+00,
#        -1.03916553e+00, -8.01618954e-01,  4.70178274e-01, -1.24884179e+00,
#         1.87118432e-01,  6.28151012e-01, -3.54555119e-01,  5.59927785e-01,
#         2.92388938e-01, -5.11313831e-01, -4.00053785e-01,  1.32942604e-01,
#        -2.52767621e-01,  3.10958877e-01,  1.07567788e+00,  8.13333097e-01,
#        -2.90156555e+00, -1.00394048e+00, -1.28675093e+00, -1.87972224e+00,
#        -6.48703697e-01, -3.72200553e-01,  8.11389278e-01,  1.16588683e-01,
#         1.15460686e-01, -4.99571506e-01, -3.57729875e-01, -1.09970663e+00,
#        -5.12149559e-01,  1.08590039e+00,  2.64012389e-01, -6.95410185e-01,
# ...

# %%
mp.style.use("classic")
mp.hist(data, alpha = 0.6, edgecolor='none')
# Out:
# (array([  6.,  18.,  86., 186., 237., 242., 143.,  59.,  19.,   4.]),
#  array([-3.20357198, -2.54244871, -1.88132545, -1.22020219, -0.55907893,
#          0.10204434,  0.7631676 ,  1.42429086,  2.08541412,  2.74653739,
#          3.40766065]),
#  <a list of 10 Patch objects>)

# %%
import numpy.random as nr

# %%
g1 = nr.normal(0,0.9,1000)

# %%
g2 = nr.normal(-1.5,1.5,1000)

# %%
g3 = nr.normal(4,1,1000)

# %%
dictarg = dict(alpha = 0.4, edgecolor='none', histtype='stepfilled')

# %%
mp.hist(g1, **dictarg)
mp.hist(g2, **dictarg)
mp.hist(g3, **dictarg)
mp.colorbar()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-147-35b4824ecc20> in <module>
#       2 mp.hist(g2, **dictarg)
#       3 mp.hist(g3, **dictarg)
# ----> 4 mp.colorbar()
#
# c:\users\madhuri\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2073         mappable = gci()
#    2074         if mappable is None:
# -> 2075             raise RuntimeError('No mappable was found to use for colorbar '
#    2076                                'creation. First define a mappable such as '
#    2077                                'an image (with imshow) or a contour set ('
#
# RuntimeError: No mappable was found to use for colorbar creation. First define a mappable such as an image (with imshow) or a contour set (with contourf).

# %%
f1 = mp.plot(x, np.sin(x-0), color = 'red', linestyle="solid", label = "sin(x)")
f2 = mp.plot(x, np.cos(x -1), color = 'g',linestyle="dashed", label = "cos(x)")
mp.axis([-1,0.5, -2,3])
mp.title("Sign wave on random numbers in numpy")
mp.xlabel("sign wave values")
mp.ylabel("random values from numpy")
mp.legend([f1,f2],['first','second'])
# Out:
# c:\users\madhuri\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x1088CF90>] instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   import sys
# c:\users\madhuri\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x1086EE30>] instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   import sys

# %%
fig = mp.figure()

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as mp

ax = mp.axes(projection='3d')

z = np.linspace(0,15, 1000)

x = np.sin(z)

y = np.cos(z)

def f(x,y):
    return np.sin(np.sqrt(x**2+y**2))

x = np.linspace(-6,6,30)

y = np.linspace(-6,6,30)

x,y = np.meshgrid(x,y)

z =f(x,y)

fig = mp.figure()


ax = mp.axes(projection='3d')

ax.contour3D(x,y,z,50,cmap='binary')
ax.view_init(90,55)

# %%
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.09448889848329178, 0.012659112021152087, 'z')

# %%
ax = mp.axes(projection='3d')

# %%
import sklearn

# %%
dir(sklearn)
# Out:
# ['__SKLEARN_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__check_build',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  'base',
#  'clone',
#  'config_context',
#  'exceptions',
#  'externals',
#  'get_config',
#  'logger',
#  'logging',
#  're',
#  'set_config',
#  'setup_module',
#  'show_versions',
#  'sys',
#  'utils',
#  'warnings']

# %%
help(sklearn)
# Out:
# Help on package sklearn:
#
# NAME
#     sklearn
#
# DESCRIPTION
#     Machine learning module for Python
# ...
#
#     sklearn is a Python module integrating classical machine
#     learning algorithms in the tightly-knit world of scientific Python
#     packages (numpy, scipy, matplotlib).
#
#     It aims to provide simple and efficient solutions to learning problems
#     that are accessible to everybody and reusable in various contexts:
#     machine-learning as a versatile tool for science and engineering.
#
#     See http://scikit-learn.org for complete documentation.
#
# PACKAGE CONTENTS
#     __check_build (package)
#     _build_utils (package)
#     _config
#     _isotonic
#     base
#     calibration
#     cluster (package)
#     compose (package)
#     covariance (package)
#     cross_decomposition (package)
#     datasets (package)
#     decomposition (package)
#     discriminant_analysis
#     dummy
#     ensemble (package)
#     exceptions
#     externals (package)
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept = True)

# %%
x = 10*nr.rand(50)
y = 2*x-5+nr.rand(50)
mp.scatter(x,y)

# %%
model.fit(x[:,np.newaxis],y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-237-890154e6b2c6> in <module>
# ----> 1 model.fit(x[:,np.newaxis],y)
#
# c:\users\madhuri\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# c:\users\madhuri\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
x = np.linspace(0,10,1000)

# %%
y = model.predict(x[:,np.newaxis])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-236-45be4bf1d2b4> in <module>
# ----> 1 y = model.predict(x[:,np.newaxis])
#
# c:\users\madhuri\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# c:\users\madhuri\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     197         return safe_sparse_dot(X, self.coef_.T,
# --> 198                                dense_output=True) + self.intercept_
#     199
#     200     def predict(self, X):
#
# ...
